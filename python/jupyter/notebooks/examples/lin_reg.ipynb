# %% [markdown]
# <div>
# <img src='../pics/banner.PNG'/>
# </div>
# <div>
# <img width="15%" src='../pics/tinlab.png'/>
# <strong>Central Statistics - Jeroen Boogaard</strong>
# </div>

# %% [markdown]
# <h1>Regression Examples</h1>

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt
from IPython.display import clear_output
import numpy as np

# %% [markdown]
# ## Random Data

# %%
n = 1024 
X = np.random.normal(0,1,n) 
Y = np.random.normal(-1,1,n)

# %% [markdown]
# **Central Statistics**

# %%
np.mean(X)
# Out:
# -0.019581966883315413

# %%
np.var(X)
# Out:
# 0.9787707702419244

# %%
np.std(X)
# Out:
# 0.9893284440679568

# %%
np.cov(X, Y)
# Out:
# array([[1.00832796, 0.06676652],
#        [0.06676652, 1.05594326]])

# %%
plt.scatter(X,Y)

# %% [markdown]
# ##Linear fit

# %%
X = np.random.randn(20)
Y = .8 * X**2 + np.random.randn(20) * .2 - 2
m, b = np.polyfit(X, Y, 1)

T = np.linspace(-2, 2, 100)
fig = plt.plot(T, m*T+b, c='r')
fig = plt.scatter(X, m*X+b, c='r')
fig = plt.scatter(X, Y)

print(m, b)
# Out:
# 0.045165689823397685 -1.3504521704128014

# %% [markdown]
# ## Quadratic fit

# %%
a, b, c = np.polyfit(X, Y, 2)

T = np.linspace(-2, 2, 100)
fig = plt.plot(T, a*T**2 + b*T + c, c='r')
fig = plt.scatter(X, a*X**2 + b*X + c, c='r')
fig = plt.scatter(X, Y)

print(m, b)
# Out:
# 0.045165689823397685 -0.013522712504411501
