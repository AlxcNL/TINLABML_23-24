# %% [markdown]
# # Bron
#
# https://en.wikipedia.org/wiki/Correlation

# %%
import numpy as np
import pandas as pd

# %%
# According to the formula we need:

# 1. Compute the average of X (avgX)
# 2. Compute the average of Y (avgY)
# 3. Compute the variation of X (stdX)
# 4. Compute the variation of Y (stdY)

# Once we have computed the ingredients above
# we must compute the sum of (Xi - avgX) * (Yi - avgY) and divide by stdX * stdY

# %%
# Let's define our linear dataset
X = np.array([0, 1, 2, 3, 4])
Y = np.array([1, 2, 3, 4, 5])

# %%
# 1. Compute the average of X (avgX)
avgX = np.average(X)

display(avgX)

# 2. Compute the average of Y (avgY)
avgY = np.average(Y)

display(avgY)
# Out:
# 2.0
# 3.0

# %%
# 3. Compute the variation of X (stdX)
stdX = np.std(X)

display(stdX)

# 4. Compute the variation of Y (stdY)
stdY = np.std(Y)

display(stdY)
# Out:
# 1.4142135623730951
# 1.4142135623730951

# %%
# Once we have computed the ingredients above
# we must compute the sum of (Xi - avgX) * (Yi - avgY) and divide by stdX * stdY
R = np.sum((X - avgX) * (Y - avgY)) / (len(X) * (stdX * stdY))

display(R)
# Out:
# 0.9999999999999998

# %%
# Let's define the pearson correlation as a function
def pearsonCorr(X, Y):
    
    avgX = np.average(X)
    avgY = np.average(Y)
    
    stdX = np.std(X)
    stdY = np.std(Y)
    
    return np.sum((X - avgX) * (Y - avgY)) / (len(X) * (stdX * stdY))

# %%
# Let's use the dataset of project 1
# df = pd.read_csv("../csv/forza_2023-05-19.csv")
df = pd.read_csv("../csv/forza_2023-05-19.csv", sep=';', header=0)

# %%
df[0:10]
# Out:
#    s_speed_x  s_speed_y  s_speed_z  s_rpm  s_gear  s_angle       s_z  \
# 0  -0.005887   -0.02797   0.000171    942       0  0.00021  0.345256
# 1  -0.005887   -0.02797   0.000171   1100       0  0.00021  0.345256
# 2  -0.005887   -0.02797   0.000171   1263       0  0.00021  0.345256
# 3  -0.005887   -0.02797   0.000171   1432       0  0.00021  0.345256
# 4  -0.005887   -0.02797   0.000171   1605       0  0.00021  0.345256
# 5  -0.005887   -0.02797   0.000171   1783       0  0.00021  0.345256
# 6  -0.005887   -0.02797   0.000171   1967       0  0.00021  0.345256
# 7  -0.005887   -0.02797   0.000171   2156       0  0.00021  0.345256
# 8  -0.005887   -0.02797   0.000171   2359       0  0.00021  0.345256
# 9  -0.005887   -0.02797   0.000171   2580       0  0.00021  0.345256
#
#    s_damage  s_track_position  s_race_position  s_distance_raced  \
# 0       0.0         -0.333363                1               0.0
# 1       0.0         -0.333363                1               0.0
# 2       0.0         -0.333363                1               0.0
# 3       0.0         -0.333363                1               0.0
# 4       0.0         -0.333363                1               0.0
# 5       0.0         -0.333363                1               0.0
# 6       0.0         -0.333363                1               0.0
# 7       0.0         -0.333363                1               0.0
# 8       0.0         -0.333363                1               0.0
# 9       0.0         -0.333363                1               0.0
#
#    s_distance_from_start  s_current_laptime  s_last_laptime  a_accelation  \
# 0            5759.100098             -0.982             0.0           1.0
# 1            5759.100098             -0.962             0.0           1.0
# 2            5759.100098             -0.942             0.0           1.0
# 3            5759.100098             -0.922             0.0           1.0
# 4            5759.100098             -0.902             0.0           1.0
# 5            5759.100098             -0.882             0.0           1.0
# 6            5759.100098             -0.862             0.0           1.0
# 7            5759.100098             -0.842             0.0           1.0
# 8            5759.100098             -0.822             0.0           1.0
# 9            5759.100098             -0.802             0.0           1.0
#
#    a_brake  a_gear   a_steer  a_clutch
# 0      0.0       1  0.455342       0.0
# 1      0.0       1  0.455342       0.0
# 2      0.0       1  0.455342       0.0
# 3      0.0       1  0.455342       0.0
# 4      0.0       1  0.455342       0.0
# 5      0.0       1  0.455342       0.0
# 6      0.0       1  0.455342       0.0
# 7      0.0       1  0.455342       0.0
# 8      0.0       1  0.455342       0.0
# 9      0.0       1  0.455342       0.0

# %%
# Look at the correlations
df.corr()
# Out:
#                        s_speed_x  s_speed_y  s_speed_z     s_rpm    s_gear  \
# s_speed_x               1.000000   0.355601   0.059532  0.905532  0.906164
# s_speed_y               0.355601   1.000000   0.089368  0.317538  0.356833
# s_speed_z               0.059532   0.089368   1.000000 -0.024930  0.154063
# s_rpm                   0.905532   0.317538  -0.024930  1.000000  0.683874
# s_gear                  0.906164   0.356833   0.154063  0.683874  1.000000
# s_angle                 0.184579   0.358307   0.030196  0.195181  0.160714
# s_z                    -0.967646  -0.335260  -0.049092 -0.888272 -0.832012
# s_damage                     NaN        NaN        NaN       NaN       NaN
# s_track_position        0.021412   0.252598   0.304272 -0.032487  0.094264
# s_race_position              NaN        NaN        NaN       NaN       NaN
# s_distance_raced       -0.025338  -0.030582  -0.075695 -0.014830 -0.042022
# s_distance_from_start  -0.227075  -0.071539  -0.215699 -0.139471 -0.282137
# s_current_laptime      -0.162087  -0.073987  -0.223814 -0.093707 -0.211707
# s_last_laptime          0.034182  -0.006806  -0.006436  0.022146  0.032394
# a_accelation           -0.002312   0.164440  -0.148004  0.098450  0.026046
# a_brake                -0.072378   0.019929  -0.049426 -0.103285 -0.019984
# a_gear                  0.907887   0.361120   0.154290  0.703190  0.993908
# a_steer                 0.257831   0.716208  -0.009825  0.262149  0.259663
# a_clutch                     NaN        NaN        NaN       NaN       NaN
#
#                         s_angle       s_z  s_damage  s_track_position  \
# s_speed_x              0.184579 -0.967646       NaN          0.021412
# s_speed_y              0.358307 -0.335260       NaN          0.252598
# s_speed_z              0.030196 -0.049092       NaN          0.304272
# s_rpm                  0.195181 -0.888272       NaN         -0.032487
# s_gear                 0.160714 -0.832012       NaN          0.094264
# s_angle                1.000000 -0.173112       NaN          0.032145
# s_z                   -0.173112  1.000000       NaN          0.010067
# s_damage                    NaN       NaN       NaN               NaN
# s_track_position       0.032145  0.010067       NaN          1.000000
# s_race_position             NaN       NaN       NaN               NaN
# s_distance_raced       0.013133  0.034440       NaN         -0.028610
# s_distance_from_start -0.058922  0.208235       NaN         -0.150888
# s_current_laptime     -0.014093  0.163131       NaN         -0.120202
# s_last_laptime         0.021736 -0.025284       NaN          0.010454
# a_accelation           0.053306  0.100369       NaN         -0.018901
# a_brake               -0.044855  0.051178       NaN         -0.083733
# a_gear                 0.161436 -0.834912       NaN          0.091803
# a_steer                0.400510 -0.260364       NaN         -0.191206
# a_clutch                    NaN       NaN       NaN               NaN
#
#                        s_race_position  s_distance_raced  \
# s_speed_x                          NaN         -0.025338
# s_speed_y                          NaN         -0.030582
# s_speed_z                          NaN         -0.075695
# s_rpm                              NaN         -0.014830
# s_gear                             NaN         -0.042022
# s_angle                            NaN          0.013133
# s_z                                NaN          0.034440
# s_damage                           NaN               NaN
# s_track_position                   NaN         -0.028610
# s_race_position                    NaN               NaN
# s_distance_raced                   NaN          1.000000
# s_distance_from_start              NaN          0.285654
# s_current_laptime                  NaN          0.295586
# s_last_laptime                     NaN          0.810210
# a_accelation                       NaN         -0.043212
# a_brake                            NaN          0.010332
# a_gear                             NaN         -0.046395
# a_steer                            NaN         -0.059627
# a_clutch                           NaN               NaN
#
#                        s_distance_from_start  s_current_laptime  \
# s_speed_x                          -0.227075          -0.162087
# s_speed_y                          -0.071539          -0.073987
# s_speed_z                          -0.215699          -0.223814
# s_rpm                              -0.139471          -0.093707
# s_gear                             -0.282137          -0.211707
# s_angle                            -0.058922          -0.014093
# s_z                                 0.208235           0.163131
# s_damage                                 NaN                NaN
# s_track_position                   -0.150888          -0.120202
# s_race_position                          NaN                NaN
# s_distance_raced                    0.285654           0.295586
# s_distance_from_start               1.000000           0.955137
# s_current_laptime                   0.955137           1.000000
# s_last_laptime                     -0.023757          -0.029158
# a_accelation                        0.024341          -0.001196
# a_brake                             0.020993           0.018691
# a_gear                             -0.280846          -0.216645
# a_steer                            -0.016343          -0.093039
# a_clutch                                 NaN                NaN
#
#                        s_last_laptime  a_accelation   a_brake    a_gear  \
# s_speed_x                    0.034182     -0.002312 -0.072378  0.907887
# s_speed_y                   -0.006806      0.164440  0.019929  0.361120
# s_speed_z                   -0.006436     -0.148004 -0.049426  0.154290
# s_rpm                        0.022146      0.098450 -0.103285  0.703190
# s_gear                       0.032394      0.026046 -0.019984  0.993908
# s_angle                      0.021736      0.053306 -0.044855  0.161436
# s_z                         -0.025284      0.100369  0.051178 -0.834912
# s_damage                          NaN           NaN       NaN       NaN
# s_track_position             0.010454     -0.018901 -0.083733  0.091803
# s_race_position                   NaN           NaN       NaN       NaN
# s_distance_raced             0.810210     -0.043212  0.010332 -0.046395
# s_distance_from_start       -0.023757      0.024341  0.020993 -0.280846
# s_current_laptime           -0.029158     -0.001196  0.018691 -0.216645
# s_last_laptime               1.000000     -0.045206  0.002122  0.029430
# a_accelation                -0.045206      1.000000 -0.243742  0.037444
# a_brake                      0.002122     -0.243742  1.000000 -0.018786
# a_gear                       0.029430      0.037444 -0.018786  1.000000
# a_steer                     -0.034104      0.176951  0.005068  0.271864
# a_clutch                          NaN           NaN       NaN       NaN
#
#                         a_steer  a_clutch
# s_speed_x              0.257831       NaN
# s_speed_y              0.716208       NaN
# s_speed_z             -0.009825       NaN
# s_rpm                  0.262149       NaN
# s_gear                 0.259663       NaN
# s_angle                0.400510       NaN
# s_z                   -0.260364       NaN
# s_damage                    NaN       NaN
# s_track_position      -0.191206       NaN
# s_race_position             NaN       NaN
# s_distance_raced      -0.059627       NaN
# s_distance_from_start -0.016343       NaN
# s_current_laptime     -0.093039       NaN
# s_last_laptime        -0.034104       NaN
# a_accelation           0.176951       NaN
# a_brake                0.005068       NaN
# a_gear                 0.271864       NaN
# a_steer                1.000000       NaN
# a_clutch                    NaN       NaN

# %%
# Let's check
R = pearsonCorr(df['s_speed_y'], df['a_steer'])

display(R)
# Out:
# 0.7162081208660015

# %%
# Let's double check
display(np.corrcoef(df['s_speed_y'], df['a_steer']))
# Out:
# array([[1.        , 0.71620812],
#        [0.71620812, 1.        ]])
